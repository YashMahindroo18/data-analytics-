# %% [markdown]
# # Pandas
# ## Pandas stands for panel data a term used for multi dimensional structured data sets

# %%
import pandas as pd

# %% [markdown]
# ## there are two core objects in pandas
#    Data Frame
#    Series

# %% [markdown]
# # Data Frame creation

# %%
new_dictionary={"day":[50,21],"night":[78,90]}
print(new_dictionary)
print("after using the function")
pd.DataFrame(new_dictionary)
# Out:
# {'day': [50, 21], 'night': [78, 90]}
# after using the function
#    day  night
# 0   50     78
# 1   21     90

# %% [markdown]
# # Series - if dataframe is a table then, series is a list in the dataframe

# %%
pd.Series([12,34,5,6,7,8])
# Out:
# 0    12
# 1    34
# 2     5
# 3     6
# 4     7
# 5     8
# dtype: int64

# %%
pd.Series([12,34,56],index=[2015,2016,2017],name="product1")
# Out:
# 2015    12
# 2016    34
# 2017    56
# Name: product1, dtype: int64

# %%
data=pd.read_csv("MakeSenseOfCensus.csv")
print(data)
# Out:
#      age  education-num  race  sex  capital-gain  capital-loss  \
# 0     39             13     4    1          2174             0
# 1     50             13     4    1             0             0
# 2     38              9     4    1             0             0
# 3     53              7     2    1             0             0
# 4     28             13     2    0             0             0
# ..   ...            ...   ...  ...           ...           ...
# 995   56              9     4    1             0             0
# 996   45             14     4    1             0             0
# 997   48             13     4    1             0             0
# 998   40             10     4    1          2580             0
# 999   39             13     4    1         15024             0
#
#      hours-per-week  income
# 0                40       0
# 1                13       0
# 2                40       0
# 3                40       0
# 4                40       0
# ..              ...     ...
# ...

# %%
data.head()
# Out:
#    age  education-num  race  sex  capital-gain  capital-loss  hours-per-week  \
# 0   39             13     4    1          2174             0              40
# 1   50             13     4    1             0             0              13
# 2   38              9     4    1             0             0              40
# 3   53              7     2    1             0             0              40
# 4   28             13     2    0             0             0              40
#
#    income
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
data.tail()
# Out:
#      age  education-num  race  sex  capital-gain  capital-loss  \
# 995   56              9     4    1             0             0
# 996   45             14     4    1             0             0
# 997   48             13     4    1             0             0
# 998   40             10     4    1          2580             0
# 999   39             13     4    1         15024             0
#
#      hours-per-week  income
# 995              55       1
# 996              45       0
# 997              58       1
# 998              40       0
# 999              50       1

# %%
data.head(11)
# Out:
#     age  education-num  race  sex  capital-gain  capital-loss  hours-per-week  \
# 0    39             13     4    1          2174             0              40
# 1    50             13     4    1             0             0              13
# 2    38              9     4    1             0             0              40
# 3    53              7     2    1             0             0              40
# 4    28             13     2    0             0             0              40
# 5    37             14     4    0             0             0              40
# 6    49              5     2    0             0             0              16
# 7    52              9     4    1             0             0              45
# 8    31             14     4    0         14084             0              50
# 9    42             13     4    1          5178             0              40
# 10   37             10     2    1             0             0              80
#
#     income
# 0        0
# ...

# %%
data.tail(9)
# Out:
#      age  education-num  race  sex  capital-gain  capital-loss  \
# 991   41             11     4    1             0             0
# 992   50              9     4    1             0             0
# 993   47              9     4    1             0             0
# 994   35              9     4    1             0             0
# 995   56              9     4    1             0             0
# 996   45             14     4    1             0             0
# 997   48             13     4    1             0             0
# 998   40             10     4    1          2580             0
# 999   39             13     4    1         15024             0
#
#      hours-per-week  income
# 991              40       0
# 992              30       0
# 993              50       1
# 994              45       0
# 995              55       1
# 996              45       0
# 997              58       1
# 998              40       0
# 999              50       1

# %%
data.shape
# Out:
# (1000, 8)

# %%
data.columns
# Out:
# Index(['age', 'education-num', 'race', 'sex', 'capital-gain', 'capital-loss',
#        'hours-per-week', 'income'],
#       dtype='object')

# %%
data.dtypes
# Out:
# age               int64
# education-num     int64
# race              int64
# sex               int64
# capital-gain      int64
# capital-loss      int64
# hours-per-week    int64
# income            int64
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             1000 non-null   int64
#  1   education-num   1000 non-null   int64
#  2   race            1000 non-null   int64
#  3   sex             1000 non-null   int64
#  4   capital-gain    1000 non-null   int64
#  5   capital-loss    1000 non-null   int64
#  6   hours-per-week  1000 non-null   int64
#  7   income          1000 non-null   int64
# dtypes: int64(8)
# memory usage: 62.6 KB

# %%
data.age
# Out:
# 0      39
# 1      50
# 2      38
# 3      53
# 4      28
#        ..
# 995    56
# 996    45
# 997    48
# 998    40
# 999    39
# Name: age, Length: 1000, dtype: int64

# %%
data["age"]
# Out:
# 0      39
# 1      50
# 2      38
# 3      53
# 4      28
#        ..
# 995    56
# 996    45
# 997    48
# 998    40
# 999    39
# Name: age, Length: 1000, dtype: int64

# %%
data["age"][4]
# Out:
# 28

# %% [markdown]
# # indexing in python
# ## iloc:index based sorting
# ## loc:label(columns) based selection

# %%
data.iloc[8]
# Out:
# age                  31
# education-num        14
# race                  4
# sex                   0
# capital-gain      14084
# capital-loss          0
# hours-per-week       50
# income                1
# Name: 8, dtype: int64

# %%
data.iloc[:,6]
# Out:
# 0      40
# 1      13
# 2      40
# 3      40
# 4      40
#        ..
# 995    55
# 996    45
# 997    58
# 998    40
# 999    50
# Name: hours-per-week, Length: 1000, dtype: int64

# %%
data.iloc[:3,6]
# Out:
# 0    40
# 1    13
# 2    40
# Name: hours-per-week, dtype: int64

# %%
data.iloc[2:4,6]
# Out:
# 2    40
# 3    40
# Name: hours-per-week, dtype: int64

# %%
data.iloc[[4,5,6],6]
# Out:
# 4    40
# 5    40
# 6    16
# Name: hours-per-week, dtype: int64

# %%
data.iloc[-5:]
# Out:
#      age  education-num  race  sex  capital-gain  capital-loss  \
# 995   56              9     4    1             0             0
# 996   45             14     4    1             0             0
# 997   48             13     4    1             0             0
# 998   40             10     4    1          2580             0
# 999   39             13     4    1         15024             0
#
#      hours-per-week  income
# 995              55       1
# 996              45       0
# 997              58       1
# 998              40       0
# 999              50       1

# %%
data.loc[0,"age"]
# Out:
# 39

# %%
data.age.unique()
# Out:
# array([39, 50, 38, 53, 28, 37, 49, 52, 31, 42, 30, 23, 32, 40, 34, 25, 43,
#        54, 35, 59, 56, 19, 20, 45, 22, 48, 21, 24, 57, 44, 41, 29, 18, 47,
#        46, 36, 79, 27, 67, 33, 76, 17, 55, 61, 70, 64, 71, 68, 66, 51, 58,
#        26, 60, 90, 75, 65, 77, 62, 63, 80, 72, 74, 69, 73, 81, 78],
#       dtype=int64)

# %%
data.age.value_counts()
# Out:
# age
# 43    33
# 31    33
# 34    32
# 23    30
# 33    30
#       ..
# 74     1
# 69     1
# 73     1
# 81     1
# 78     1
# Name: count, Length: 66, dtype: int64

# %%
data.age==34
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Name: age, Length: 1000, dtype: bool

# %%
data.loc[data.age==34]
# Out:
#      age  education-num  race  sex  capital-gain  capital-loss  \
# 15    34              4     0    1             0             0
# 94    34             13     4    1             0             0
# 151   34              9     4    0             0             0
# 177   34              9     2    1             0             0
# 185   34              9     2    1             0             0
# 282   34             12     2    0             0             0
# 311   34             14     1    1          7298             0
# 393   34             13     4    1          7688             0
# 394   34              9     4    0             0             0
# 403   34             11     4    0             0             0
# 418   34              7     2    1             0             0
# 419   34              9     4    0             0             0
# 436   34              9     2    1           594             0
# 437   34             10     4    0             0             0
# ...

# %%
data.loc[(data.age==34)|(data.age==44)]
# Out:
#      age  education-num  race  sex  capital-gain  capital-loss  \
# 15    34              4     0    1             0             0
# 47    44             14     4    0             0             0
# 84    44              9     4    0         14344             0
# 94    34             13     4    1             0             0
# 101   44             13     4    1         15024             0
# 151   34              9     4    0             0             0
# 162   44             14     1    0             0             0
# 177   34              9     2    1             0             0
# 180   44             10     2    1             0             0
# 185   34              9     2    1             0             0
# 210   44              9     2    1             0             0
# 276   44             10     4    1          7298             0
# 282   34             12     2    0             0             0
# 311   34             14     1    1          7298             0
# ...

# %%
data.loc[(data.race==4)&(data.age==34)]
# Out:
#      age  education-num  race  sex  capital-gain  capital-loss  \
# 94    34             13     4    1             0             0
# 151   34              9     4    0             0             0
# 393   34             13     4    1          7688             0
# 394   34              9     4    0             0             0
# 403   34             11     4    0             0             0
# 419   34              9     4    0             0             0
# 437   34             10     4    0             0             0
# 493   34              9     4    0             0             0
# 513   34             10     4    1             0             0
# 519   34             13     4    1             0             0
# 558   34              9     4    0             0             0
# 626   34              9     4    1             0             0
# 657   34              9     4    1             0             0
# 682   34              9     4    1             0             0
# ...

# %%
data["visitor"]='everyone'
data["visitor"]
# Out:
# 0      everyone
# 1      everyone
# 2      everyone
# 3      everyone
# 4      everyone
#          ...
# 995    everyone
# 996    everyone
# 997    everyone
# 998    everyone
# 999    everyone
# Name: visitor, Length: 1000, dtype: object

# %%
data
# Out:
#      age  education-num  race  sex  capital-gain  capital-loss  \
# 0     39             13     4    1          2174             0
# 1     50             13     4    1             0             0
# 2     38              9     4    1             0             0
# 3     53              7     2    1             0             0
# 4     28             13     2    0             0             0
# ..   ...            ...   ...  ...           ...           ...
# 995   56              9     4    1             0             0
# 996   45             14     4    1             0             0
# 997   48             13     4    1             0             0
# 998   40             10     4    1          2580             0
# 999   39             13     4    1         15024             0
#
#      hours-per-week  income   visitor
# 0                40       0  everyone
# 1                13       0  everyone
# 2                40       0  everyone
# 3                40       0  everyone
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 data.info
#
# NameError: name 'data' is not defined
